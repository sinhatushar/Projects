# %%
# !python gen_anchors.py -c config.json
# Out:
# Using TensorFlow backend.
# parsing /content/drive/My Drive/Rod-keras_yolo2-master/339-annotation.csv csv file can took a while, wait please.
# 100% 1018/1018 [00:02<00:00, 436.65it/s]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2019-05-09 23:12:20.155510: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-09 23:12:20.155675: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x20a31e0 executing computations on platform Host. Devices:
# 2019-05-09 23:12:20.155702: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# ...

# %%
#### Training without loading pretrained weights ####
#### iou_threshold : 0.5 ####
#### img-size : 64*320 ####

# !python train.py -c config.json
# Out:
# Using TensorFlow backend.
# 2019-05-09 23:20:53.703232: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-09 23:20:53.703442: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2b3f1e0 executing computations on platform Host. Devices:
# 2019-05-09 23:20:53.703475: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-09 23:20:53.859994: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-09 23:20:53.860485: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2b3edc0 executing computations on platform CUDA. Devices:
# 2019-05-09 23:20:53.860527: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# ...

# %%
#### Training with loading pretrained weights ####
#### iou_threshold : 0.5 ####
#### img-size : 64*320 ####

# !python train.py -c config.json
# Out:
# Using TensorFlow backend.
# 2019-05-10 16:57:01.582543: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-10 16:57:01.582890: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x20ed1e0 executing computations on platform Host. Devices:
# 2019-05-10 16:57:01.582947: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-10 16:57:01.870536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-10 16:57:01.871105: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x20ecdc0 executing computations on platform CUDA. Devices:
# 2019-05-10 16:57:01.871174: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# ...

# %%
#### Training without loading pretrained weights ####
#### iou_threshold : 0.5 ####
#### img-size : 64*320 resized to 416*416 ####
# !python train.py -c config.json
# Out:
# Using TensorFlow backend.
# 2019-05-11 11:30:38.418208: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-05-11 11:30:38.418526: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2e091e0 executing computations on platform Host. Devices:
# 2019-05-11 11:30:38.418567: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-11 11:30:38.665627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-11 11:30:38.666164: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2e08dc0 executing computations on platform CUDA. Devices:
# 2019-05-11 11:30:38.666248: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# ...
