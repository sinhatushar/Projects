# %%
# !python gen_anchors.py -c config.json
# Out:
# Using TensorFlow backend.
# parsing /content/drive/My Drive/Keras-yolo2/1747-annotation.csv csv file can took a while, wait please.
# 100% 5242/5242 [00:23<00:00, 219.73it/s]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2019-05-14 04:41:13.469458: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-14 04:41:13.469663: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2f271e0 executing computations on platform Host. Devices:
# 2019-05-14 04:41:13.471360: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# ...

# %%
#### Training without loading pretrained weights ####
#### iou_threshold : 0.1 ####
#### Original img-size : 416*416 ####
#### Training - 1 #### 
# !python train.py -c config.json
# Out:
# Using TensorFlow backend.
# 2019-05-14 12:51:08.888130: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-05-14 12:51:08.888535: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x216b1e0 executing computations on platform Host. Devices:
# 2019-05-14 12:51:08.888571: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-14 12:51:09.162638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-14 12:51:09.163171: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x216adc0 executing computations on platform CUDA. Devices:
# 2019-05-14 12:51:09.163202: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# ...

# %%
#### DETECTION ON TRAINED MODEL #####

# %%
#### Confidence threshold value is set to 0.1 ####
# !python3 predict.py -c config.json -w /home/tushar/Desktop/Server/Rod-keras_yolo2-master/pre-weights-not-loaded-416_416-iou-point-one_bestLoss-1.h5  -i /home/tushar/Desktop/Server/Rod-keras_yolo2-master/Test-images/Arie_Alter_1.jpg

# %%
##Result of above command##
'''
Using TensorFlow backend.
2019-05-15 11:01:55.428138: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
2019-05-15 11:01:55.644892: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
2019-05-15 11:01:55.664161: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x4749610 executing computations on platform Host. Devices:
2019-05-15 11:01:55.664297: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
Instructions for updating:
Colocations handled automatically by placer.
Loading pretrained weights: ./backend_weights/full_yolo_backend.h5
(13, 13)
_________________________________________________________________
Layer (type)                 Output Shape              Param #   
=================================================================
input_1 (InputLayer)         (None, 416, 416, 3)       0         
_________________________________________________________________
Full_YOLO_backend (Model)    (None, 13, 13, 1024)      50547936  
_________________________________________________________________
Detection_layer (Conv2D)     (None, 13, 13, 40)        41000     
_________________________________________________________________
YOLO_output (Reshape)        (None, 13, 13, 5, 8)      0         
=================================================================
Total params: 50,588,936
Trainable params: 50,568,264
Non-trainable params: 20,672
_________________________________________________________________
/home/tushar/Desktop/Server/Rod-keras_yolo2-master/keras_yolov2/utils.py:75: RuntimeWarning: invalid value encountered in double_scalars
  return float(intersect) / union
0 16 15 16 15
0 48 15 48 15
0 80 15 80 15
0 111 15 111 15
0 144 15 144 15
2 -1 9 296 18
0 176 15 176 15
0 208 15 208 15
0 240 15 240 15
0 272 15 272 15
1 303 15 303 15
1 335 15 335 15
0 367 15 367 15
0 399 15 399 15
0 16 47 16 47
0 48 47 48 47
0 80 47 80 47
0 111 47 111 47
0 144 47 144 47
0 -2 43 297 52
0 176 47 176 47
0 207 47 207 47
0 239 47 239 47
0 271 47 271 47
0 303 48 303 48
0 335 48 335 48
0 366 47 366 47
0 399 47 399 47
0 16 79 16 79
0 48 79 48 79
0 80 79 80 79
0 111 79 111 79
0 144 79 144 79
0 -2 74 298 84
0 176 79 176 79
0 207 79 207 79
0 239 79 239 79
I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
2019-05-15 11:06:03.156415: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
2019-05-15 11:06:03.156823: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x5db75c0 executing computations on platform Host. Devices:
2019-05-15 11:06:03.156887: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
Instructions for updating:
Colocations handled automatically by placer.
Loading pretrained weights: ./backend_weights/full_yolo_backend.h5
(13, 13)
_________________________________________________________________
Layer (type)                 Output Shape              Param #   
=================================================================
input_1 (InputLayer)         (None, 416, 416, 3)       0         
_________________________________________________________________
Full_YOLO_backend (Model)    (None, 13, 13, 1024)      50547936  
_________________________________________________________________
Detection_layer (Conv2D)     (None, 13, 13, 40)        41000     
_________________________________________________________________
YOLO_output (Reshape)        (None, 13, 13, 5, 8)      0         
=================================================================
Total params: 50,588,936
Trainable params: 50,568,264
Non-trainable params: 20,672
_________________________________________________________________
2 -1 9 296 18
1 boxes are found
Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x7f87e919acf8>>
Traceback (most recent call last):
  File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 738, in __del__
TypeError: 'NoneType' object is not callable
'''

# %%
##Confidence Threshold value is set to 0.2
# !python3 predict.py -c config.json -w /home/tushar/Desktop/Server/Rod-keras_yolo2-master/pre-weights-not-loaded-416_416-iou-point-one_bestLoss-1.h5  -i /home/tushar/Desktop/Server/Rod-keras_yolo2-master/Test-images/Arie_Alter_1.jpg

# %%
##Result of above command##

'''
Using TensorFlow backend.
2019-05-15 11:12:08.383430: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
2019-05-15 11:12:08.404403: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
2019-05-15 11:12:08.404762: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x57f6500 executing computations on platform Host. Devices:
2019-05-15 11:12:08.404801: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
Instructions for updating:
Colocations handled automatically by placer.
Loading pretrained weights: ./backend_weights/full_yolo_backend.h5
(13, 13)
_________________________________________________________________
Layer (type)                 Output Shape              Param #   
=================================================================
input_1 (InputLayer)         (None, 416, 416, 3)       0         
_________________________________________________________________
Full_YOLO_backend (Model)    (None, 13, 13, 1024)      50547936  
_________________________________________________________________
Detection_layer (Conv2D)     (None, 13, 13, 40)        41000     
_________________________________________________________________
YOLO_output (Reshape)        (None, 13, 13, 5, 8)      0         
=================================================================
Total params: 50,588,936
Trainable params: 50,568,264
Non-trainable params: 20,672
_________________________________________________________________
/home/tushar/Desktop/Server/Rod-keras_yolo2-master/keras_yolov2/utils.py:75: RuntimeWarning: invalid value encountered in double_scalars
  return float(intersect) / union
2 -1 9 296 18
0 -2 43 297 52
0 -2 74 298 84
1 365 143 365 143
1 366 175 366 175
1 396 174 396 174
1 366 207 366 207
1 396 206 396 206
1 366 238 366 238
1 396 238 396 238
1 366 270 366 270
1 396 270 396 270
1 366 302 366 302
1 396 302 396 302
1 366 334 366 334
1 396 334 396 334
1 366 366 366 366
1 396 366 396 366
18 boxes are found
'''
