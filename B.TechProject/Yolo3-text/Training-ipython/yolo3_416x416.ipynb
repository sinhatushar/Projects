# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd gdrive/My\ Drive/BTP1/
# Out:
# /content/gdrive/My Drive/BTP1

# %%
cd YOLOv3-TensorFlow/
# Out:
# /content/gdrive/My Drive/BTP1/YOLOv3-TensorFlow

# %%
ls
# Out:
# '1747-train-images-416*416'/   make-339.py
#  339-annotaion/                model.py
#  339-annotaion-server.txt      model.pyc
#  339-annotaion.txt             __pycache__/
#  339-train-images/             test_single_image.py
# 'checkpoint-416*416'/          train.py
# 'checkpoint-64*320'/           utils/
#  convert_weight.py             video_test.py
#  data/                         yolo3-annoation-with-path-second/
#  eval.py                       yolo3-annoation-with-path-second-server/
#  get_kmeans.py

# %%
# !python3 convert_weight.py
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# 2019-05-14 22:55:34.440543: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-14 22:55:34.440957: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x176c680 executing computations on platform Host. Devices:
# 2019-05-14 22:55:34.441019: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-14 22:55:34.706843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python2 train.py
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:139: map_and_batch (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.map_and_batch(...)`.
# WARNING:tensorflow:From train.py:138: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
# ...

# %%
# !python eval.py
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From eval.py:66: map_and_batch (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.map_and_batch(...)`.
# WARNING:tensorflow:From eval.py:65: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
# ...

# %%
# !python eval.py --restore_path /content/gdrive/My Drive/BTP1/YOLOv3-TensorFlow/checkpoint/model-step_8000_loss_0.059482_lr_0.001.data-00000-of-00001
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# usage: eval.py [-h] [--eval_file EVAL_FILE] [--restore_path RESTORE_PATH]
#                [--anchor_path ANCHOR_PATH] [--class_name_path CLASS_NAME_PATH]
#                [--batch_size BATCH_SIZE]
#                [--img_size [IMG_SIZE [IMG_SIZE ...]]]
#                [--num_threads NUM_THREADS]
#                [--prefetech_buffer PREFETECH_BUFFER]
# eval.py: error: unrecognized arguments: Drive/BTP1/YOLOv3-TensorFlow/checkpoint/model-step_8000_loss_0.059482_lr_0.001.data-00000-of-00001
